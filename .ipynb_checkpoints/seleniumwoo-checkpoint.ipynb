# %%
import ctypes 
ctypes.windll.shell32.SetCurrentProcessExplicitAppUserModelID("myappid")
from tkinter import *
import winsound
from tkinter import messagebox
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
driver = webdriver.Chrome('C:\\Users\\ASUS\\Desktop\\.ipynb_checkpoints\\chromedriver.exe')
driver.get('https://wootalk.today/key/%E6%88%90%E4%BA%BA%E6%A8%A1%E5%BC%8F')

# %%
n=1

# %%
##目前完整版
def leave_button():
    global n,click_btn
    click_btn=1
    driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()
    try:
        driver.implicitly_wait(1)
        driver.find_element_by_id("popup-yes").click()
    except Exception as e:
        print('(error)def n=',n)
    top.destroy()
    
def command_restart():
    global restart
    restart=1
    driver.refresh()
    error.destroy()

def close_window_one():
    global restart
    restart=0
    error.destroy()
def close_window():
    global click_btn
    click_btn=0
    top.destroy()

while n!=0:
    time.sleep(2) 
    try:
        driver.implicitly_wait(10)
        driver.find_element_by_id('startButton').click()
        driver.implicitly_wait(10)
        c=driver.find_element_by_id('messageInput')
        driver.find_element_by_id("messageInput").clear()
        c.send_keys('嗨尋找喜愛腹肌的女生')
        ##c.send_keys('哈囉 女生')
        driver.implicitly_wait(15)
        driver.find_element_by_css_selector("#messages > div:nth-child(4)").text
        print(driver.find_element_by_css_selector("#messages > div:nth-child(4)").text)
        driver.implicitly_wait(10)
        c.send_keys(Keys.RETURN)
        time.sleep(8)
        texts_length = len(driver.find_elements_by_xpath("//div[@class=\"system text \"]"))
        print('起始text_length',texts_length)
    except Exception as e:
        print("stop1",e)
        try:
                                 sys_text=driver.find_element_by_class_name("system.text ").text
                                 leave_error='離開'
                                 leave_ans = leave_error  in sys_text
                                 link_error='連結'
                                 link_ans = link_error in sys_text
                                 repair_error='緊急維護'
                                 repair_ans= repair_error in sys_text
                                 start_error="開始聊天"
                                 start_ans=start_error in sys_text

        except Exception as e:
            print("stop2",e)
            try:
                driver.find_element_by_id("sloganText")
                driver.refresh()
                n+=1
            except Exception as e:
                        print("stop3",e)

                        error = Tk()
                        error.title("WOO出錯啦(第1階段)")
                        error.geometry("400x200+450+300")
                        error_scale = Canvas(height=150, width=300)
                        my_label = Label(error, text = 'WOO壞掉啦!',font=12)
                        btn_leave = Button(text = "關閉視窗",command = close_window_one,anchor='e').place(x=140,y=100)
                        btn_restart = Button(text = "重新開始",command = command_restart,anchor='e').place(x=210,y=100)
                        my_label.pack()
                        time.sleep(1)
                        error.bell()
                        error.iconbitmap('C:\\Users\ASUS\\Desktop\\doc\\autoproject\\icon\\woo.ico')
                        winsound.PlaySound('C:\\Users\\ASUS\\Desktop\\.ipynb_checkpoints\\alart.wav',winsound.SND_ASYNC)
                        error.mainloop()
                        if restart==1:
                                n+=1
                        elif restart==0:
                                break   
        else:
            try:
                if leave_ans == True:
                            driver.find_element_by_id('changeButton').click()
                            n+=1

                elif start_ans == True:
                    try:
                            print("start_ans",start_ans)
                            driver.implicitly_wait(10)
                            driver.find_element_by_id('changeButton').click()
                            driver.implicitly_wait(10)
                            driver.find_element_by_id("popup-yes").click()
                            n+=1
                    except Exception as e:
                        print('卡住',e)

                elif repair_ans == True:
                        error = Tk()
                        error.title("woo出錯啦(第2-1階段)")
                        error.geometry("400x200+450+300")
                        error_scale = Canvas(height=150, width=300)
                        my_label = Label(error, text = 'WOO緊急維護!',font=12)
                        btn_leave = Button(text = "關閉視窗",command = close_window_one,anchor='e').place(x=140,y=100)
                        btn_restart = Button(text = "重新開始",command = command_restart,anchor='e').place(x=210,y=100)
                        my_label.pack()
                        time.sleep(1)
                        error.iconbitmap('C:\\Users\ASUS\\Desktop\\doc\\autoproject\\icon\\woo.ico')
                        winsound.PlaySound('C:\\Users\\ASUS\\Desktop\\.ipynb_checkpoints\\alart.wav',winsound.SND_ASYNC)
                        error.mainloop()
                        if restart==1:
                                n+=1
                        elif restart==0:
                                break
                elif link_ans==True:
                        ##連結驗證
                        error = Tk()
                        error.title("woo出錯啦(第2-1階段)")
                        error.geometry("400x200+450+300")
                        error_scale = Canvas(height=150, width=300)
                        my_label = Label(error, text = sys_text,font=12)
                        btn_leave = Button(text = "關閉視窗",command = close_window_one,anchor='e').place(x=140,y=100)
                        btn_restart = Button(text = "重新開始",command = command_restart,anchor='e').place(x=210,y=100)
                        my_label.pack()
                        time.sleep(1)
                        error.iconbitmap('C:\\Users\ASUS\\Desktop\\doc\\autoproject\\icon\\woo.ico')
                        winsound.PlaySound('C:\\Users\\ASUS\\Desktop\\.ipynb_checkpoints\\alart.wav',winsound.SND_ASYNC)
                        error.mainloop()
                        if restart==1:
                                n+=1
                        elif restart==0:
                                break
                else:
                        driver.refresh()
                        n+=1
            except Exception as e:
                print("stop4",e)
                driver.refresh()
                n+=1    
            
            
    
        
    else :
        if texts_length==5:
            print('text_length五',texts_length)
            print("第",n,"個第一階段離開")
            driver.implicitly_wait(10)
            driver.find_element_by_id('changeButton').click()
            n+=1
        elif texts_length==7:
            print('text_length七',texts_length)
            print("第",n,"個第一階段離開")
            driver.implicitly_wait(10)
            driver.find_element_by_id('changeButton').click()
            n+=1
        else:
            ##第一階段未離開
            try:
                driver.implicitly_wait(5)
                stranger_text=driver.find_element_by_css_selector('div.stranger.text').text

            except Exception as e:
                print("stop5",e)
                try:  
                    driver.implicitly_wait(10)
                    driver.find_elements_by_class_name("system.text ")
                    s=len(driver.find_elements_by_class_name("system.text "))
            
                    if s%2!=0:
                        ##s=基數代表離開
                        print("s=",s)
                        print("第",n,"個無人回話已離開")
                        driver.implicitly_wait(5)
                        #driver.find_element_by_id('changeButton').click()
                        driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()
                        n+=1
                    else :
                        ##s=偶數代表未離開
                        print("s=",s)
                        print("第",n,"個無人回話未離開")
                        driver.implicitly_wait(10)
                        driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()
                        driver.implicitly_wait(10)
                        driver.find_element_by_id("popup-yes").click()
                        n+=1

                except Exception as e:
                    print("stop6",e)
                    try:
                                 driver.find_element_by_class_name("system.text ").text
                                 sys_text2=driver.find_element_by_class_name("system.text").text
                                 leave_ans2 = leave_error  in sys_text2
                                 link_ans2 = link_error in sys_text2
                    except Exception as e:
                        print("stop7",e)
                        try:
                            driver.find_element_by_id("sloganText")
                            driver.refresh()
                            n+=1
                        except Exception as e:

                            error = Tk()
                            error.title("WOO出錯啦(第3階段)")
                            error.geometry("400x200+450+300")
                            error_scale = Canvas(height=150, width=300)
                            my_label = Label(error, text = 'WOO壞掉啦!',font=12)
                            btn_leave = Button(text = "關閉視窗",command = close_window_one,anchor='e').place(x=140,y=100)
                            btn_restart = Button(text = "重新開始",command = command_restart,anchor='e').place(x=210,y=100)
                            my_label.pack()
                            time.sleep(1)
                            error.iconbitmap('C:\\Users\ASUS\\Desktop\\doc\\autoproject\\icon\\woo.ico')
                            winsound.PlaySound('C:\\Users\\ASUS\\Desktop\\.ipynb_checkpoints\\alart.wav',winsound.SND_ASYNC)
                            error.bell()
                            error.mainloop()
                            if restart==1:
                                    n+=1
                            elif restart==0:
                                    break

                    else:
                        if leave_ans2 == True:
                                        driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()
                                        n+=1
                        elif link_ans2==True:
                            error = Tk()
                            error.title("woo出錯啦(第3-1階段)")
                            error.geometry("400x200+450+300")
                            error_scale = Canvas(height=150, width=300)
                            my_label = Label(error, text = sys_text,font=12)
                            btn_leave = Button(text = "關閉視窗",command = close_window_one,anchor='e').place(x=140,y=100)
                            btn_restart = Button(text = "重新開始",command = command_restart,anchor='e').place(x=210,y=100)
                            my_label.pack()
                            time.sleep(1)
                            error.iconbitmap('C:\\Users\ASUS\\Desktop\\doc\\autoproject\\icon\\woo.ico')
                            winsound.PlaySound('C:\\Users\\ASUS\\Desktop\\.ipynb_checkpoints\\alart.wav',winsound.SND_ASYNC)
                            error.mainloop()
                            if restart==1:
                                n+=1
                            elif restart==0:
                                break
                            
                        else:
                                        print('卡二')
                                        driver.refresh()
                                        n+=1


            else:
                    print("有人回話")
                    ##有人回話未離開情況下
                    ignore_array=["男","賴",'line','女嗎','找女','叔','滾','台中','你媽','耖','機掰','雞掰','操','找妹']
                    global change_check
                    change_check=0
                    for i in range(0,len(ignore_array)):
                         
                        ignore_ans = ignore_array[i] in stranger_text
                        print(stranger_text," ",ignore_array[i],ignore_ans)
                        if ignore_ans == True:
                            print('抓到白癡啦')
                            change_check+=1
                            try:
                                driver.implicitly_wait(10)
                                driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()
                                driver.implicitly_wait(3)
                                driver.find_element_by_id("popup-yes").click()
                                n+=1
                                print('success')
                            except:
                                    n+=1
                    text_special=['找','女','妹','姊','姐','幹','娘']
                    text_special_ans1 = text_special[0] and text_special[1] in stranger_text
                    text_special_ans2 = text_special[0] and text_special[2] in stranger_text
                    text_special_ans3 = text_special[0] and text_special[3] in stranger_text
                    text_special_ans4 = text_special[0] and text_special[4] in stranger_text
                    text_special_ans5 = text_special[5] and text_special[6] in stranger_text             
                    if text_special_ans1 == True:
                            print('抓到找女啦')
                            change_check+=1
                            try:
                                driver.implicitly_wait(10)
                                driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()
                                driver.implicitly_wait(3)
                                driver.find_element_by_id("popup-yes").click()
                                n+=1
                                print('success')
                            except:
                                    n+=1
                    elif text_special_ans2 == True:
                            print('抓到找妹啦')
                            change_check+=1
                            try:
                                driver.implicitly_wait(10)
                                driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()
                                driver.implicitly_wait(3)
                                driver.find_element_by_id("popup-yes").click()
                                n+=1
                                print('success')
                            except:
                                    n+=1  
                    elif text_special_ans3 == True:
                            print('抓到找姊姊啦')
                            change_check+=1
                            try:
                                driver.implicitly_wait(10)
                                driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()
                                driver.implicitly_wait(3)
                                driver.find_element_by_id("popup-yes").click()
                                n+=1
                                print('success')
                            except:
                                    n+=1 
                    elif text_special_ans4 == True:
                            print('抓到找姐姐啦')
                            change_check+=1
                            try:
                                driver.implicitly_wait(10)
                                driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()
                                driver.implicitly_wait(3)
                                driver.find_element_by_id("popup-yes").click()
                                n+=1
                                print('success')
                            except:
                                    n+=1 
                    elif text_special_ans5 == True:
                            print('還敢罵幹你娘阿')
                            change_check+=1
                            try:
                                driver.implicitly_wait(10)
                                driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()
                                driver.implicitly_wait(3)
                                driver.find_element_by_id("popup-yes").click()
                                n+=1
                                print('success')
                            except:
                                    n+=1   
                    print('change_check=',change_check)
                        
                        
                        
                         
                    if change_check ==0: 
                        print('change_check',change_check)
                                ##有人回話且沒有禁用字
                        driver.implicitly_wait(1)
                        note=len(driver.find_elements_by_class_name("system.text "))
                        if note%2!=0:
                                    ##note=基數代表離開
                                    print("note=",note)
                                    print("第",n,"個有人回話已離開",stranger_text)
                                    driver.implicitly_wait(10)
                                    driver.find_element_by_id('changeButton').click()
                                    n+=1
            
                        elif note%2==0:
                                        ##note=偶數代表未離開
                                        print("note=",note)
                                        print("第",n,"個有人回話未離開",stranger_text)  
                                        top = Tk()
                                        top.title("WOO有人留下")
                                        top.geometry("400x200+450+300")
                                        top_scale = Canvas(height=150, width=300)
                                        my_label = Label(top, text =('有人留言',stranger_text),font=12)
                                        leave_btn=Button(text='離開對話',command=leave_button).place(x=210,y=100)
                                        button = Button(text = "關閉視窗",command = close_window,anchor='e').place(x=140,y=100)
                                        my_label.pack()
                                        time.sleep(1)
                                        top.iconbitmap('C:\\Users\ASUS\\Desktop\\doc\\autoproject\\icon\\woo.ico')
                                        winsound.PlaySound('C:\\Users\\ASUS\\Desktop\\.ipynb_checkpoints\\alart.wav',winsound.SND_ASYNC)
                                        top.mainloop()
                                        if click_btn==1:
                                                n+=1
                                        elif click_btn==0:
                                            break
# Out:
# stop1 Message: element not interactable
#   (Session info: chrome=87.0.4280.141)
#
# stop1 Message: element not interactable
#   (Session info: chrome=87.0.4280.141)
#
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 72 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 73 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 74 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 75 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 6
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 9
# 第 76 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：台北有🐔物
# (
# 剛剛)   男 False
# 陌生人：台北有🐔物
# (
# 剛剛)   賴 False
# 陌生人：台北有🐔物
# (
# 剛剛)   line False
# 陌生人：台北有🐔物
# (
# 剛剛)   女嗎 False
# 陌生人：台北有🐔物
# (
# 剛剛)   找女 False
# 陌生人：台北有🐔物
# (
# 剛剛)   叔 False
# 陌生人：台北有🐔物
# (
# 剛剛)   滾 False
# 陌生人：台北有🐔物
# (
# 剛剛)   台中 False
# 陌生人：台北有🐔物
# (
# 剛剛)   你媽 False
# 陌生人：台北有🐔物
# (
# 剛剛)   耖 False
# 陌生人：台北有🐔物
# (
# 剛剛)   機掰 False
# 陌生人：台北有🐔物
# (
# 剛剛)   雞掰 False
# 陌生人：台北有🐔物
# (
# 剛剛)   操 False
# 陌生人：台北有🐔物
# (
# 剛剛)   找妹 False
# change_check= 0
# change_check 0
# note= 6
# 第 77 個有人回話未離開 陌生人：台北有🐔物
# (
# 剛剛)
# (error)def n= 77
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 78 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 79 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 80 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 81 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 82 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 83 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 7
# 第 84 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 85 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 86 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 87 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 88 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 89 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 90 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 91 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 92 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 93 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 94 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 95 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 6
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 9
# 第 96 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 97 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 6
# 第 98 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 99 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 100 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 101 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 102 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 103 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 104 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 105 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 106 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：多大
# (
# 剛剛)   男 False
# 陌生人：多大
# (
# 剛剛)   賴 False
# 陌生人：多大
# (
# 剛剛)   line False
# 陌生人：多大
# (
# 剛剛)   女嗎 False
# 陌生人：多大
# (
# 剛剛)   找女 False
# 陌生人：多大
# (
# 剛剛)   叔 False
# 陌生人：多大
# (
# 剛剛)   滾 False
# 陌生人：多大
# (
# 剛剛)   台中 False
# 陌生人：多大
# (
# 剛剛)   你媽 False
# 陌生人：多大
# (
# 剛剛)   耖 False
# 陌生人：多大
# (
# 剛剛)   機掰 False
# 陌生人：多大
# (
# 剛剛)   雞掰 False
# 陌生人：多大
# (
# 剛剛)   操 False
# 陌生人：多大
# (
# 剛剛)   找妹 False
# change_check= 0
# change_check 0
# note= 6
# 第 107 個有人回話未離開 陌生人：多大
# (
# 剛剛)
# (error)def n= 107
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 108 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 7
# 第 109 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 110 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 111 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 112 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 113 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 6
# 有人回話
# 陌生人：午安 男人喔
# (
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：午安 男人喔
# (
# 剛剛)   賴 False
# 陌生人：午安 男人喔
# (
# 剛剛)   line False
# 陌生人：午安 男人喔
# (
# 剛剛)   女嗎 False
# 陌生人：午安 男人喔
# (
# 剛剛)   找女 False
# 陌生人：午安 男人喔
# (
# 剛剛)   叔 False
# 陌生人：午安 男人喔
# (
# 剛剛)   滾 False
# 陌生人：午安 男人喔
# (
# 剛剛)   台中 False
# 陌生人：午安 男人喔
# (
# 剛剛)   你媽 False
# 陌生人：午安 男人喔
# (
# 剛剛)   耖 False
# 陌生人：午安 男人喔
# (
# 剛剛)   機掰 False
# 陌生人：午安 男人喔
# (
# 剛剛)   雞掰 False
# 陌生人：午安 男人喔
# (
# 剛剛)   操 False
# 陌生人：午安 男人喔
# (
# 剛剛)   找妹 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 115 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 116 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 117 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 118 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 119 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：幾歲呢
# (
# 行動裝置
# 剛剛)   男 False
# 陌生人：幾歲呢
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：幾歲呢
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：幾歲呢
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：幾歲呢
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：幾歲呢
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：幾歲呢
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：幾歲呢
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：幾歲呢
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：幾歲呢
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：幾歲呢
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：幾歲呢
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：幾歲呢
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：幾歲呢
# (
# 行動裝置
# 剛剛)   找妹 False
# change_check= 0
# change_check 0
# note= 6
# 第 120 個有人回話未離開 陌生人：幾歲呢
# (
# 行動裝置
# 剛剛)
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 121 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 122 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 123 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 124 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 125 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 126 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 127 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 128 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 129 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 130 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 131 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 132 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 133 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 134 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 135 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 136 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 6
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 8
# 第 137 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 138 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 7
# 第 139 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 140 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 141 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 142 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 143 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 144 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 145 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 146 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 147 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 148 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 149 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 150 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 151 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 152 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 153 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 154 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 155 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 156 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 157 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 158 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 159 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 160 個第一階段離開
# stop1 Message: no such element: Unable to locate element: {"method":"css selector","selector":"#messages > div:nth-child(4)"}
#   (Session info: chrome=87.0.4280.141)
#
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 162 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 163 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 164 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 165 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 166 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 167 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 168 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 169 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 170 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 171 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 172 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 173 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 174 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 175 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 176 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 177 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 178 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 6
# 第 179 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 180 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 181 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 182 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 183 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 6
# 第 184 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 185 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 186 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 187 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 188 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 189 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 190 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 191 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 192 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 6
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 9
# 第 193 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 194 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 195 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 196 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 197 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 198 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 199 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 200 個第一階段離開
# stop1 Message: no such element: Unable to locate element: {"method":"css selector","selector":"#messages > div:nth-child(4)"}
#   (Session info: chrome=87.0.4280.141)
#
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 202 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 203 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 204 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 205 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 206 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 6
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 9
# 第 207 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 208 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 209 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 210 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 211 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 212 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 213 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 214 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 215 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 216 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 217 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 6
# 第 218 個無人回話未離開
# stop1 Message: no such element: Unable to locate element: {"method":"css selector","selector":"#messages > div:nth-child(4)"}
#   (Session info: chrome=87.0.4280.141)
#
# stop1 Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="startButton"]"}
#   (Session info: chrome=87.0.4280.141)
#
# stop2 Message: no such element: Unable to locate element: {"method":"css selector","selector":".system.text "}
#   (Session info: chrome=87.0.4280.141)
#
# stop3 Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="sloganText"]"}
#   (Session info: chrome=87.0.4280.141)
#
# stop1 Message: element not interactable
#   (Session info: chrome=87.0.4280.141)
#
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：還沒找到嗎
# (
# 行動裝置
# 剛剛)   男 False
# 陌生人：還沒找到嗎
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：還沒找到嗎
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：還沒找到嗎
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：還沒找到嗎
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：還沒找到嗎
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：還沒找到嗎
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：還沒找到嗎
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：還沒找到嗎
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：還沒找到嗎
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：還沒找到嗎
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：還沒找到嗎
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：還沒找到嗎
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：還沒找到嗎
# (
# 行動裝置
# 剛剛)   找妹 False
# change_check= 0
# change_check 0
# note= 6
# 第 222 個有人回話未離開 陌生人：還沒找到嗎
# (
# 行動裝置
# 剛剛)
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 223 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 224 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 225 個第一階段離開
# stop1 Message: no such element: Unable to locate element: {"method":"css selector","selector":"#messages > div:nth-child(4)"}
#   (Session info: chrome=87.0.4280.141)
#
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 227 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 228 個第一階段離開
# stop1 Message: no such element: Unable to locate element: {"method":"css selector","selector":"#messages > div:nth-child(4)"}
#   (Session info: chrome=87.0.4280.141)
#
# stop1 Message: no such element: Unable to locate element: {"method":"css selector","selector":"#messages > div:nth-child(4)"}
#   (Session info: chrome=87.0.4280.141)
#
# stop1 Message: no such element: Unable to locate element: {"method":"css selector","selector":"#messages > div:nth-child(4)"}
#   (Session info: chrome=87.0.4280.141)
#
# stop1 Message: no such element: Unable to locate element: {"method":"css selector","selector":"#messages > div:nth-child(4)"}
#   (Session info: chrome=87.0.4280.141)
#
# stop1 Message: no such element: Unable to locate element: {"method":"css selector","selector":"#messages > div:nth-child(4)"}
#   (Session info: chrome=87.0.4280.141)
#
# stop1 Message: no such element: Unable to locate element: {"method":"css selector","selector":"#messages > div:nth-child(4)"}
#   (Session info: chrome=87.0.4280.141)
#
# stop1 Message: element not interactable
#   (Session info: chrome=87.0.4280.141)
#
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 236 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 6
# 第 237 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 238 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 239 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 240 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 241 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 242 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 243 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 244 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 245 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 246 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 247 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 248 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 249 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 250 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 6
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 8
# 第 251 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 6
# 第 252 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 253 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 6
# 第 254 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 6
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 8
# 第 255 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 256 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 257 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 258 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 259 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 260 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 261 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 262 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 263 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 264 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 265 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 266 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 6
# 第 267 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 268 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 269 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 270 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 271 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 272 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 273 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 274 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 275 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 276 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 277 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 278 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 279 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 280 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 281 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：男
# (
# 行動裝置
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：男
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   找妹 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 283 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 284 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：男生
# (
# 行動裝置
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：男生
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：男生
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：男生
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：男生
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：男生
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：男生
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：男生
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：男生
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：男生
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：男生
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：男生
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：男生
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：男生
# (
# 行動裝置
# 剛剛)   找妹 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 286 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 287 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   男 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   line True
# 抓到白癡啦
# success
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   找妹 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 289 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 290 個第一階段離開
# stop1 Message: no such element: Unable to locate element: {"method":"css selector","selector":"#messages > div:nth-child(4)"}
#   (Session info: chrome=87.0.4280.141)
#
# 今日 (1月12日)
# 起始text_length 3
# 有人回話
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   男 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   line True
# 抓到白癡啦
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   找妹 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：嗨男
# (
# 行動裝置
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：嗨男
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：嗨男
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：嗨男
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：嗨男
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：嗨男
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：嗨男
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：嗨男
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：嗨男
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：嗨男
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：嗨男
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：嗨男
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：嗨男
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：嗨男
# (
# 行動裝置
# 剛剛)   找妹 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 294 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 295 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 6
# 第 296 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 297 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 298 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 299 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 300 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 301 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 302 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 303 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 304 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 6
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 8
# 第 305 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 306 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 307 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 308 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 309 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 6
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 9
# 第 310 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 311 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 6
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 9
# 第 312 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 313 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 314 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 315 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 316 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 317 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 318 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 6
# 第 319 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：男
# (
# 行動裝置
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：男
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   找妹 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   男 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   line True
# 抓到白癡啦
# success
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：masculine
# (
# 行動裝置
# 剛剛)   找妹 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 322 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 323 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 324 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 325 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 326 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 327 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 328 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 6
# 第 329 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 6
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 9
# 第 330 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 331 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 332 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 333 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 334 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 335 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 336 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 337 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 338 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 6
# 第 339 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 340 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 341 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 342 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 7
# 第 343 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 6
# 第 344 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 345 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 7
# 第 346 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 347 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 348 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 349 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 350 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 351 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 352 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 353 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 354 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 6
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 9
# 第 355 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 7
# 第 356 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 357 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 358 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 359 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 360 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 361 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 362 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 363 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 364 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 6
# 有人回話
# 陌生人：屏東大一男 ：）
# (
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：屏東大一男 ：）
# (
# 剛剛)   賴 False
# 陌生人：屏東大一男 ：）
# (
# 剛剛)   line False
# 陌生人：屏東大一男 ：）
# (
# 剛剛)   女嗎 False
# 陌生人：屏東大一男 ：）
# (
# 剛剛)   找女 False
# 陌生人：屏東大一男 ：）
# (
# 剛剛)   叔 False
# 陌生人：屏東大一男 ：）
# (
# 剛剛)   滾 False
# 陌生人：屏東大一男 ：）
# (
# 剛剛)   台中 False
# 陌生人：屏東大一男 ：）
# (
# 剛剛)   你媽 False
# 陌生人：屏東大一男 ：）
# (
# 剛剛)   耖 False
# 陌生人：屏東大一男 ：）
# (
# 剛剛)   機掰 False
# 陌生人：屏東大一男 ：）
# (
# 剛剛)   雞掰 False
# 陌生人：屏東大一男 ：）
# (
# 剛剛)   操 False
# 陌生人：屏東大一男 ：）
# (
# 剛剛)   找妹 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 366 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 367 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 368 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 369 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 370 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 371 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 372 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 373 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 374 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 375 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 376 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 377 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 378 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 379 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 6
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 9
# 第 380 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 381 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 382 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 383 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 384 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=87.0.4280.141)
#
# s= 6
# 第 385 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   男 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   賴 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   line False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   女嗎 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   找女 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   叔 True
# 抓到白癡啦
# success
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   滾 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   台中 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   你媽 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   耖 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   機掰 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   雞掰 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   操 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   找妹 False
# 抓到找女啦
# success
# change_check= 2
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   男 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   賴 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   line False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   女嗎 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   找女 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   叔 True
# 抓到白癡啦
# success
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   滾 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   台中 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   你媽 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   耖 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   機掰 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   雞掰 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   操 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   找妹 False
# 抓到找女啦
# success
# change_check= 2
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   男 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   賴 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   line False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   女嗎 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   找女 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   叔 True
# 抓到白癡啦
# success
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   滾 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   台中 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   你媽 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   耖 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   機掰 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   雞掰 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   操 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   找妹 False
# 抓到找女啦
# success
# change_check= 2
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 6
# 有人回話
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   男 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   賴 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   line False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   女嗎 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   找女 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   叔 True
# 抓到白癡啦
# success
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   滾 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   台中 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   你媽 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   耖 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   機掰 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   雞掰 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   操 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   找妹 False
# 抓到找女啦
# success
# change_check= 2
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 394 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 395 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 396 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 397 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 398 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 399 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 400 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 401 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 402 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 403 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 404 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 405 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 406 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 407 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 408 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   男 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   賴 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   line False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   女嗎 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   找女 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   叔 True
# 抓到白癡啦
# success
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   滾 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   台中 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   你媽 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   耖 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   機掰 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   雞掰 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   操 False
# 陌生人：大叔喔 女孩嗎
# (
# 剛剛)   找妹 False
# 抓到找女啦
# success
# change_check= 2
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 7
# text_length七 7
# 第 411 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 412 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：我有
# (
# App
# 剛剛)   男 False
# 陌生人：我有
# (
# App
# 剛剛)   賴 False
# 陌生人：我有
# (
# App
# 剛剛)   line False
# 陌生人：我有
# (
# App
# 剛剛)   女嗎 False
# 陌生人：我有
# (
# App
# 剛剛)   找女 False
# 陌生人：我有
# (
# App
# 剛剛)   叔 False
# 陌生人：我有
# (
# App
# 剛剛)   滾 False
# 陌生人：我有
# (
# App
# 剛剛)   台中 False
# 陌生人：我有
# (
# App
# 剛剛)   你媽 False
# 陌生人：我有
# (
# App
# 剛剛)   耖 False
# 陌生人：我有
# (
# App
# 剛剛)   機掰 False
# 陌生人：我有
# (
# App
# 剛剛)   雞掰 False
# 陌生人：我有
# (
# App
# 剛剛)   操 False
# 陌生人：我有
# (
# App
# 剛剛)   找妹 False
# change_check= 0
# change_check 0
# note= 6
# 第 413 個有人回話未離開 陌生人：我有
# (
# App
# 剛剛)

# %%
test='找色女孩'
ans= test.find("找女")
print(ans)
print(stranger_text)
# Out:
# -1
# 陌生人：找色女孩
# (
# 行動裝置
# 剛剛)

# %%
x=len(driver.find_elements_by_class_name("system.text "))
x
s
# Out:
# 6

# %%
s.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-a7d0f55a5125> in <module>()
#       1
# ----> 2 s.info()
#
# AttributeError: 'int' object has no attribute 'info'

# %%
driver.find_element_by_css_selector("div.system.text")
len(driver.find_element_by_css_selector("div.system.text"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-803aff82599d> in <module>()
#       1 driver.find_element_by_css_selector("div.system.text")
# ----> 2 len(driver.find_element_by_css_selector("div.system.text"))
#
# TypeError: object of type 'WebElement' has no len()

# %%
driver.find_element_by_id('changeButton').click()

# %%
note=len(driver.find_elements_by_class_name("system.text "))

# %%
driver.find_elements_by_class_name("system text ")
driver.find_element_by_class_name("start").click()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-b905e4ef48f0> in <module>()
# ----> 1 driver.find_elements_class_name("system text ")
#
# AttributeError: 'WebDriver' object has no attribute 'find_elements_class_name'

# %%
from tkinter import *
from tkinter import messagebox
"""
在python 2.*版本若要將彈出視窗導入到類別裡面的話，是import "tkMessageBox"
而如果跟我一樣是使用python 3.*版本的話才是import "messagebox"
"""
top = Tk()
top.title("有人留下")
top.geometry("400x200+450+300")
top_scale = Canvas(height=150, width=300)
my_label = Label(top, text = '是妹子嗎!', bg = 'white',anchor="CENTER")
my_label.pack()
top.mainloop()

# %%
import tkinter as tk
import os
 
def show_messagebox(string):
    os.environ["DISPLAY"]=":0.0"
    root = tk.Tk()
    root.title('消息框')
    root.geometry('190x80+300+300')
    label = tk.Label(root, text=string, font='宋体 -14', pady=8)
    label.pack()
    tk.mainloop()
        
def do_ring(times):
    for i in range(0,times):
        os.system("paplay {} --volume=32768".format('ring.wav'))
 
def warning(string):
    print("do warning")
    do_ring(10)
    show_messagebox(string)
 

warning("测试一下")
# Out:
# do warning
