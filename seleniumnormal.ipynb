# %%
import ctypes 
ctypes.windll.shell32.SetCurrentProcessExplicitAppUserModelID("myappid")
from tkinter import *
import winsound
from tkinter import messagebox
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
driver = webdriver.Chrome('C:\\Users\\ASUS\\Desktop\\.ipynb_checkpoints\\chromedriver.exe')
driver.get('https://wootalk.today/')

# %%
n=1

# %%
##目前完整版
def leave_button():
    global n,click_btn
    click_btn=1
    driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()
    try:
        driver.implicitly_wait(1)
        driver.find_element_by_id("popup-yes").click()
    except Exception as e:
        print('(error)def n=',n)
    top.destroy()
    
def command_restart():
    global restart
    restart=1
    driver.refresh()
    error.destroy()

def close_window_one():
    global restart
    restart=0
    error.destroy()
def close_window():
    global click_btn
    click_btn=0
    top.destroy()

while n!=0:
    time.sleep(2) 
    try:
        driver.implicitly_wait(10)
        driver.find_element_by_id('startButton').click()
        driver.implicitly_wait(10)
        c=driver.find_element_by_id('messageInput')
        driver.find_element_by_id("messageInput").clear()
        c.send_keys('嗨尋找腹肌控的女生')
        ##c.send_keys('哈囉 女生')
        driver.implicitly_wait(15)
        driver.find_element_by_css_selector("#messages > div:nth-child(4)").text
        print(driver.find_element_by_css_selector("#messages > div:nth-child(4)").text)
        driver.implicitly_wait(10)
        c.send_keys(Keys.RETURN)
        time.sleep(8)
        texts_length = len(driver.find_elements_by_xpath("//div[@class=\"system text \"]"))
        print('起始text_length',texts_length)
    except Exception as e:
        print("stop1",e)
        try:
                                 sys_text=driver.find_element_by_class_name("system.text ").text
                                 leave_error='離開'
                                 leave_ans = leave_error  in sys_text
                                 link_error='連結'
                                 link_ans = link_error in sys_text
                                 repair_error='緊急維護'
                                 repair_ans= repair_error in sys_text
                                 start_error="開始聊天"
                                 start_ans=start_error in sys_text

        except Exception as e:
            print("stop2",e)
            try:
                driver.find_element_by_id("sloganText")
                driver.refresh()
                n+=1
            except Exception as e:
                        print("stop3",e)

                        error = Tk()
                        error.title("WOO出錯啦(第1階段)")
                        error.geometry("400x200+450+300")
                        error_scale = Canvas(height=150, width=300)
                        my_label = Label(error, text = 'WOO壞掉啦!',font=12)
                        btn_leave = Button(text = "關閉視窗",command = close_window_one,anchor='e').place(x=140,y=100)
                        btn_restart = Button(text = "重新開始",command = command_restart,anchor='e').place(x=210,y=100)
                        my_label.pack()
                        time.sleep(1)
                        error.bell()
                        error.iconbitmap('C:\\Users\ASUS\\Desktop\\doc\\autoproject\\icon\\woo.ico')
                        winsound.PlaySound('C:\\Users\\ASUS\\Desktop\\.ipynb_checkpoints\\alart.wav',winsound.SND_ASYNC)
                        error.mainloop()
                        if restart==1:
                                n+=1
                        elif restart==0:
                                break   
        else:
            try:
                if leave_ans == True:
                            driver.find_element_by_id('changeButton').click()
                            n+=1

                elif start_ans == True:
                    try:
                            print("start_ans",start_ans)
                            driver.implicitly_wait(10)
                            driver.find_element_by_id('changeButton').click()
                            driver.implicitly_wait(10)
                            driver.find_element_by_id("popup-yes").click()
                            n+=1
                    except Exception as e:
                        print('卡住',e)

                elif repair_ans == True:
                        error = Tk()
                        error.title("woo出錯啦(第2-1階段)")
                        error.geometry("400x200+450+300")
                        error_scale = Canvas(height=150, width=300)
                        my_label = Label(error, text = 'WOO緊急維護!',font=12)
                        btn_leave = Button(text = "關閉視窗",command = close_window_one,anchor='e').place(x=140,y=100)
                        btn_restart = Button(text = "重新開始",command = command_restart,anchor='e').place(x=210,y=100)
                        my_label.pack()
                        time.sleep(1)
                        error.iconbitmap('C:\\Users\ASUS\\Desktop\\doc\\autoproject\\icon\\woo.ico')
                        winsound.PlaySound('C:\\Users\\ASUS\\Desktop\\.ipynb_checkpoints\\alart.wav',winsound.SND_ASYNC)
                        error.mainloop()
                        if restart==1:
                                n+=1
                        elif restart==0:
                                break
                elif link_ans==True:
                        ##連結驗證
                        error = Tk()
                        error.title("woo出錯啦(第2-1階段)")
                        error.geometry("400x200+450+300")
                        error_scale = Canvas(height=150, width=300)
                        my_label = Label(error, text = sys_text,font=12)
                        btn_leave = Button(text = "關閉視窗",command = close_window_one,anchor='e').place(x=140,y=100)
                        btn_restart = Button(text = "重新開始",command = command_restart,anchor='e').place(x=210,y=100)
                        my_label.pack()
                        time.sleep(1)
                        error.iconbitmap('C:\\Users\ASUS\\Desktop\\doc\\autoproject\\icon\\woo.ico')
                        winsound.PlaySound('C:\\Users\\ASUS\\Desktop\\.ipynb_checkpoints\\alart.wav',winsound.SND_ASYNC)
                        error.mainloop()
                        if restart==1:
                                n+=1
                        elif restart==0:
                                break
                else:
                        driver.refresh()
                        n+=1
            except Exception as e:
                print("stop4",e)
                driver.refresh()
                n+=1    
            
            
    
        
    else :
        if texts_length==5:
            print('text_length五',texts_length)
            print("第",n,"個第一階段離開")
            driver.implicitly_wait(10)
            driver.find_element_by_id('changeButton').click()
            n+=1
        elif texts_length==7:
            print('text_length七',texts_length)
            print("第",n,"個第一階段離開")
            driver.implicitly_wait(10)
            driver.find_element_by_id('changeButton').click()
            n+=1
        else:
            ##第一階段未離開
            try:
                driver.implicitly_wait(5)
                stranger_text=driver.find_element_by_css_selector('div.stranger.text').text

            except Exception as e:
                print("stop5",e)
                try:  
                    driver.implicitly_wait(10)
                    driver.find_elements_by_class_name("system.text ")
                    s=len(driver.find_elements_by_class_name("system.text "))
            
                    if s%2!=0:
                        ##s=基數代表離開
                        print("s=",s)
                        print("第",n,"個無人回話已離開")
                        driver.implicitly_wait(5)
                        #driver.find_element_by_id('changeButton').click()
                        driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()
                        n+=1
                    else :
                        ##s=偶數代表未離開
                        print("s=",s)
                        print("第",n,"個無人回話未離開")
                        driver.implicitly_wait(10)
                        driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()
                        driver.implicitly_wait(10)
                        driver.find_element_by_id("popup-yes").click()
                        n+=1

                except Exception as e:
                    print("stop6",e)
                    try:
                                 driver.find_element_by_class_name("system.text ").text
                                 sys_text2=driver.find_element_by_class_name("system.text").text
                                 leave_ans2 = leave_error  in sys_text2
                                 link_ans2 = link_error in sys_text2
                    except Exception as e:
                        print("stop7",e)
                        try:
                            driver.find_element_by_id("sloganText")
                            driver.refresh()
                            n+=1
                        except Exception as e:

                            error = Tk()
                            error.title("WOO出錯啦(第3階段)")
                            error.geometry("400x200+450+300")
                            error_scale = Canvas(height=150, width=300)
                            my_label = Label(error, text = 'WOO壞掉啦!',font=12)
                            btn_leave = Button(text = "關閉視窗",command = close_window_one,anchor='e').place(x=140,y=100)
                            btn_restart = Button(text = "重新開始",command = command_restart,anchor='e').place(x=210,y=100)
                            my_label.pack()
                            time.sleep(1)
                            error.iconbitmap('C:\\Users\ASUS\\Desktop\\doc\\autoproject\\icon\\woo.ico')
                            winsound.PlaySound('C:\\Users\\ASUS\\Desktop\\.ipynb_checkpoints\\alart.wav',winsound.SND_ASYNC)
                            error.bell()
                            error.mainloop()
                            if restart==1:
                                    n+=1
                            elif restart==0:
                                    break

                    else:
                        if leave_ans2 == True:
                                        driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()
                                        n+=1
                        elif link_ans2==True:
                            error = Tk()
                            error.title("woo出錯啦(第3-1階段)")
                            error.geometry("400x200+450+300")
                            error_scale = Canvas(height=150, width=300)
                            my_label = Label(error, text = sys_text,font=12)
                            btn_leave = Button(text = "關閉視窗",command = close_window_one,anchor='e').place(x=140,y=100)
                            btn_restart = Button(text = "重新開始",command = command_restart,anchor='e').place(x=210,y=100)
                            my_label.pack()
                            time.sleep(1)
                            error.iconbitmap('C:\\Users\ASUS\\Desktop\\doc\\autoproject\\icon\\woo.ico')
                            winsound.PlaySound('C:\\Users\\ASUS\\Desktop\\.ipynb_checkpoints\\alart.wav',winsound.SND_ASYNC)
                            error.mainloop()
                            if restart==1:
                                n+=1
                            elif restart==0:
                                break
                            
                        else:
                                        print('卡二')
                                        driver.refresh()
                                        n+=1


            else:
                    print("有人回話")
                    ##有人回話未離開情況下
                    ignore_array=["男","賴",'line','女嗎','找女','叔','滾','台中','你媽','耖','機掰','雞掰','操','找妹','約嗎']
                    global change_check
                    change_check=0
                    for i in range(0,len(ignore_array)):
                         
                        ignore_ans = ignore_array[i] in stranger_text
                        print(stranger_text," ",ignore_array[i],ignore_ans)
                        if ignore_ans == True:
                            print('抓到白癡啦')
                            change_check+=1
                            try:
                                driver.implicitly_wait(10)
                                driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()
                                driver.implicitly_wait(3)
                                driver.find_element_by_id("popup-yes").click()
                                n+=1
                                print('success')
                            except:
                                    n+=1
                    text_special=['找','女','妹','姊','姐','幹','娘']
                    text_special_ans1 = text_special[0] and text_special[1] in stranger_text
                    text_special_ans2 = text_special[0] and text_special[2] in stranger_text
                    text_special_ans3 = text_special[0] and text_special[3] in stranger_text
                    text_special_ans4 = text_special[0] and text_special[4] in stranger_text
                    text_special_ans5 = text_special[5] and text_special[6] in stranger_text             
                    if text_special_ans1 == True:
                            print('抓到找女啦')
                            change_check+=1
                            try:
                                driver.implicitly_wait(10)
                                driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()
                                driver.implicitly_wait(3)
                                driver.find_element_by_id("popup-yes").click()
                                n+=1
                                print('success')
                            except:
                                    n+=1
                    elif text_special_ans2 == True:
                            print('抓到找妹啦')
                            change_check+=1
                            try:
                                driver.implicitly_wait(10)
                                driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()
                                driver.implicitly_wait(3)
                                driver.find_element_by_id("popup-yes").click()
                                n+=1
                                print('success')
                            except:
                                    n+=1  
                    elif text_special_ans3 == True:
                            print('抓到找姊姊啦')
                            change_check+=1
                            try:
                                driver.implicitly_wait(10)
                                driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()
                                driver.implicitly_wait(3)
                                driver.find_element_by_id("popup-yes").click()
                                n+=1
                                print('success')
                            except:
                                    n+=1 
                    elif text_special_ans4 == True:
                            print('抓到找姐姐啦')
                            change_check+=1
                            try:
                                driver.implicitly_wait(10)
                                driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()
                                driver.implicitly_wait(3)
                                driver.find_element_by_id("popup-yes").click()
                                n+=1
                                print('success')
                            except:
                                    n+=1 
                    elif text_special_ans5 == True:
                            print('還敢罵幹你娘阿')
                            change_check+=1
                            try:
                                driver.implicitly_wait(10)
                                driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()
                                driver.implicitly_wait(3)
                                driver.find_element_by_id("popup-yes").click()
                                n+=1
                                print('success')
                            except:
                                    n+=1   
                    print('change_check=',change_check)
                        
                        
                        
                         
                    if change_check ==0: 
                        print('change_check',change_check)
                                ##有人回話且沒有禁用字
                        driver.implicitly_wait(1)
                        note=len(driver.find_elements_by_class_name("system.text "))
                        if note%2!=0:
                                    ##note=基數代表離開
                                    print("note=",note)
                                    print("第",n,"個有人回話已離開",stranger_text)
                                    driver.implicitly_wait(10)
                                    driver.find_element_by_id('changeButton').click()
                                    n+=1
            
                        elif note%2==0:
                                        ##note=偶數代表未離開
                                        print("note=",note)
                                        print("第",n,"個有人回話未離開",stranger_text)  
                                        top = Tk()
                                        top.title("WOO有人留下")
                                        top.geometry("400x200+450+300")
                                        top_scale = Canvas(height=150, width=300)
                                        my_label = Label(top, text =('有人留言',stranger_text),font=12)
                                        leave_btn=Button(text='離開對話',command=leave_button).place(x=210,y=100)
                                        button = Button(text = "關閉視窗",command = close_window,anchor='e').place(x=140,y=100)
                                        my_label.pack()
                                        time.sleep(1)
                                        top.iconbitmap('C:\\Users\ASUS\\Desktop\\doc\\autoproject\\icon\\woo.ico')
                                        winsound.PlaySound('C:\\Users\\ASUS\\Desktop\\.ipynb_checkpoints\\alart.wav',winsound.SND_ASYNC)
                                        top.mainloop()
                                        if click_btn==1:
                                                n+=1
                                        elif click_btn==0:
                                            break
# Out:
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 1 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 2 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 3 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 4 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：我就是
# (
# 剛剛)   男 False
# 陌生人：我就是
# (
# 剛剛)   賴 False
# 陌生人：我就是
# (
# 剛剛)   line False
# 陌生人：我就是
# (
# 剛剛)   女嗎 False
# 陌生人：我就是
# (
# 剛剛)   找女 False
# 陌生人：我就是
# (
# 剛剛)   叔 False
# 陌生人：我就是
# (
# 剛剛)   滾 False
# 陌生人：我就是
# (
# 剛剛)   台中 False
# 陌生人：我就是
# (
# 剛剛)   你媽 False
# 陌生人：我就是
# (
# 剛剛)   耖 False
# 陌生人：我就是
# (
# 剛剛)   機掰 False
# 陌生人：我就是
# (
# 剛剛)   雞掰 False
# 陌生人：我就是
# (
# 剛剛)   操 False
# 陌生人：我就是
# (
# 剛剛)   找妹 False
# 陌生人：我就是
# (
# 剛剛)   約嗎 False
# change_check= 0
# change_check 0
# note= 6
# 第 5 個有人回話未離開 陌生人：我就是
# (
# 剛剛)
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 6
# 第 6 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 6
# 第 7 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 8 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 7
# 第 9 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：午安
# (
# 剛剛)   男 False
# 陌生人：午安
# (
# 剛剛)   賴 False
# 陌生人：午安
# (
# 剛剛)   line False
# 陌生人：午安
# (
# 剛剛)   女嗎 False
# 陌生人：午安
# (
# 剛剛)   找女 False
# 陌生人：午安
# (
# 剛剛)   叔 False
# 陌生人：午安
# (
# 剛剛)   滾 False
# 陌生人：午安
# (
# 剛剛)   台中 False
# 陌生人：午安
# (
# 剛剛)   你媽 False
# 陌生人：午安
# (
# 剛剛)   耖 False
# 陌生人：午安
# (
# 剛剛)   機掰 False
# 陌生人：午安
# (
# 剛剛)   雞掰 False
# 陌生人：午安
# (
# 剛剛)   操 False
# 陌生人：午安
# (
# 剛剛)   找妹 False
# 陌生人：午安
# (
# 剛剛)   約嗎 False
# change_check= 0
# change_check 0
# note= 6
# 第 10 個有人回話未離開 陌生人：午安
# (
# 剛剛)
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 11 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 12 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 13 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 14 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 7
# 第 15 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：女
# (
# 剛剛)   男 False
# 陌生人：女
# (
# 剛剛)   賴 False
# 陌生人：女
# (
# 剛剛)   line False
# 陌生人：女
# (
# 剛剛)   女嗎 False
# 陌生人：女
# (
# 剛剛)   找女 False
# 陌生人：女
# (
# 剛剛)   叔 False
# 陌生人：女
# (
# 剛剛)   滾 False
# 陌生人：女
# (
# 剛剛)   台中 False
# 陌生人：女
# (
# 剛剛)   你媽 False
# 陌生人：女
# (
# 剛剛)   耖 False
# 陌生人：女
# (
# 剛剛)   機掰 False
# 陌生人：女
# (
# 剛剛)   雞掰 False
# 陌生人：女
# (
# 剛剛)   操 False
# 陌生人：女
# (
# 剛剛)   找妹 False
# 陌生人：女
# (
# 剛剛)   約嗎 False
# 抓到找女啦
# success
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 17 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 18 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 19 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：男 19歲
# (
# 行動裝置
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：男 19歲
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：男 19歲
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：男 19歲
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：男 19歲
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：男 19歲
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：男 19歲
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：男 19歲
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：男 19歲
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：男 19歲
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：男 19歲
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：男 19歲
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：男 19歲
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：男 19歲
# (
# 行動裝置
# 剛剛)   找妹 False
# 陌生人：男 19歲
# (
# 行動裝置
# 剛剛)   約嗎 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 21 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 22 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 23 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 24 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：腹肌控？
# (
# 行動裝置
# 剛剛)   男 False
# 陌生人：腹肌控？
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：腹肌控？
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：腹肌控？
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：腹肌控？
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：腹肌控？
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：腹肌控？
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：腹肌控？
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：腹肌控？
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：腹肌控？
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：腹肌控？
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：腹肌控？
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：腹肌控？
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：腹肌控？
# (
# 行動裝置
# 剛剛)   找妹 False
# 陌生人：腹肌控？
# (
# 行動裝置
# 剛剛)   約嗎 False
# change_check= 0
# change_check 0
# note= 6
# 第 25 個有人回話未離開 陌生人：腹肌控？
# (
# 行動裝置
# 剛剛)
# (error)def n= 25
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：請問
# (
# 行動裝置
# 剛剛)   男 False
# 陌生人：請問
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：請問
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：請問
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：請問
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：請問
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：請問
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：請問
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：請問
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：請問
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：請問
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：請問
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：請問
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：請問
# (
# 行動裝置
# 剛剛)   找妹 False
# 陌生人：請問
# (
# 行動裝置
# 剛剛)   約嗎 False
# change_check= 0
# change_check 0
# note= 6
# 第 26 個有人回話未離開 陌生人：請問
# (
# 行動裝置
# 剛剛)
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 27 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 28 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 6
# 第 29 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：我
# (
# App
# 剛剛)   男 False
# 陌生人：我
# (
# App
# 剛剛)   賴 False
# 陌生人：我
# (
# App
# 剛剛)   line False
# 陌生人：我
# (
# App
# 剛剛)   女嗎 False
# 陌生人：我
# (
# App
# 剛剛)   找女 False
# 陌生人：我
# (
# App
# 剛剛)   叔 False
# 陌生人：我
# (
# App
# 剛剛)   滾 False
# 陌生人：我
# (
# App
# 剛剛)   台中 False
# 陌生人：我
# (
# App
# 剛剛)   你媽 False
# 陌生人：我
# (
# App
# 剛剛)   耖 False
# 陌生人：我
# (
# App
# 剛剛)   機掰 False
# 陌生人：我
# (
# App
# 剛剛)   雞掰 False
# 陌生人：我
# (
# App
# 剛剛)   操 False
# 陌生人：我
# (
# App
# 剛剛)   找妹 False
# 陌生人：我
# (
# App
# 剛剛)   約嗎 False
# change_check= 0
# change_check 0
# note= 6
# 第 30 個有人回話未離開 陌生人：我
# (
# App
# 剛剛)
# (error)def n= 30
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 31 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 32 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 33 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：男
# (
# 行動裝置
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：男
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   找妹 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   約嗎 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：男
# (
# 行動裝置
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：男
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   找妹 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   約嗎 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 36 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 37 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 38 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 7
# 第 39 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 40 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 7
# 第 41 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 42 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 43 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 44 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 6
# 第 45 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 46 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 7
# 第 47 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 48 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 49 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：女
# (
# App
# 剛剛)   男 False
# 陌生人：女
# (
# App
# 剛剛)   賴 False
# 陌生人：女
# (
# App
# 剛剛)   line False
# 陌生人：女
# (
# App
# 剛剛)   女嗎 False
# 陌生人：女
# (
# App
# 剛剛)   找女 False
# 陌生人：女
# (
# App
# 剛剛)   叔 False
# 陌生人：女
# (
# App
# 剛剛)   滾 False
# 陌生人：女
# (
# App
# 剛剛)   台中 False
# 陌生人：女
# (
# App
# 剛剛)   你媽 False
# 陌生人：女
# (
# App
# 剛剛)   耖 False
# 陌生人：女
# (
# App
# 剛剛)   機掰 False
# 陌生人：女
# (
# App
# 剛剛)   雞掰 False
# 陌生人：女
# (
# App
# 剛剛)   操 False
# 陌生人：女
# (
# App
# 剛剛)   找妹 False
# 陌生人：女
# (
# App
# 剛剛)   約嗎 False
# 抓到找女啦
# success
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 6
# 第 51 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：我也在找欸
# (
# 行動裝置
# 剛剛)   男 False
# 陌生人：我也在找欸
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：我也在找欸
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：我也在找欸
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：我也在找欸
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：我也在找欸
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：我也在找欸
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：我也在找欸
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：我也在找欸
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：我也在找欸
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：我也在找欸
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：我也在找欸
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：我也在找欸
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：我也在找欸
# (
# 行動裝置
# 剛剛)   找妹 False
# 陌生人：我也在找欸
# (
# 行動裝置
# 剛剛)   約嗎 False
# change_check= 0
# change_check 0
# note= 6
# 第 52 個有人回話未離開 陌生人：我也在找欸
# (
# 行動裝置
# 剛剛)
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 53 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 54 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 55 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 56 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 57 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 7
# 第 58 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 59 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 60 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 61 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 62 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 6
# 第 63 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 64 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 65 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 66 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 67 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 68 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 69 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 70 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 71 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 72 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 73 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 74 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 6
# 第 75 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 76 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：00
# (
# 剛剛)   男 False
# 陌生人：00
# (
# 剛剛)   賴 False
# 陌生人：00
# (
# 剛剛)   line False
# 陌生人：00
# (
# 剛剛)   女嗎 False
# 陌生人：00
# (
# 剛剛)   找女 False
# 陌生人：00
# (
# 剛剛)   叔 False
# 陌生人：00
# (
# 剛剛)   滾 False
# 陌生人：00
# (
# 剛剛)   台中 False
# 陌生人：00
# (
# 剛剛)   你媽 False
# 陌生人：00
# (
# 剛剛)   耖 False
# 陌生人：00
# (
# 剛剛)   機掰 False
# 陌生人：00
# (
# 剛剛)   雞掰 False
# 陌生人：00
# (
# 剛剛)   操 False
# 陌生人：00
# (
# 剛剛)   找妹 False
# 陌生人：00
# (
# 剛剛)   約嗎 False
# change_check= 0
# change_check 0
# note= 6
# 第 77 個有人回話未離開 陌生人：00
# (
# 剛剛)
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 78 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 7
# 第 79 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 80 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：你有嗎
# (
# 行動裝置
# 剛剛)   男 False
# 陌生人：你有嗎
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：你有嗎
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：你有嗎
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：你有嗎
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：你有嗎
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：你有嗎
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：你有嗎
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：你有嗎
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：你有嗎
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：你有嗎
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：你有嗎
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：你有嗎
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：你有嗎
# (
# 行動裝置
# 剛剛)   找妹 False
# 陌生人：你有嗎
# (
# 行動裝置
# 剛剛)   約嗎 False
# change_check= 0
# change_check 0
# note= 6
# 第 81 個有人回話未離開 陌生人：你有嗎
# (
# 行動裝置
# 剛剛)
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 82 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 83 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 84 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 85 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 86 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 87 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   台中 True
# 抓到白癡啦
# success
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   找妹 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   約嗎 False
# change_check= 2
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 90 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：新北男生21妳呢
# (
# 行動裝置
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：新北男生21妳呢
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：新北男生21妳呢
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：新北男生21妳呢
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：新北男生21妳呢
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：新北男生21妳呢
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：新北男生21妳呢
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：新北男生21妳呢
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：新北男生21妳呢
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：新北男生21妳呢
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：新北男生21妳呢
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：新北男生21妳呢
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：新北男生21妳呢
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：新北男生21妳呢
# (
# 行動裝置
# 剛剛)   找妹 False
# 陌生人：新北男生21妳呢
# (
# 行動裝置
# 剛剛)   約嗎 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   台中 True
# 抓到白癡啦
# success
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   找妹 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   約嗎 False
# change_check= 2
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 94 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：我有🐔🐔😂
# (
# 行動裝置
# 剛剛)   男 False
# 陌生人：我有🐔🐔😂
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：我有🐔🐔😂
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：我有🐔🐔😂
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：我有🐔🐔😂
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：我有🐔🐔😂
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：我有🐔🐔😂
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：我有🐔🐔😂
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：我有🐔🐔😂
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：我有🐔🐔😂
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：我有🐔🐔😂
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：我有🐔🐔😂
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：我有🐔🐔😂
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：我有🐔🐔😂
# (
# 行動裝置
# 剛剛)   找妹 False
# 陌生人：我有🐔🐔😂
# (
# 行動裝置
# 剛剛)   約嗎 False
# change_check= 0
# change_check 0
# note= 6
# 第 95 個有人回話未離開 陌生人：我有🐔🐔😂
# (
# 行動裝置
# 剛剛)
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 96 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 97 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 6
# 第 98 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：女
# (
# 剛剛)   男 False
# 陌生人：女
# (
# 剛剛)   賴 False
# 陌生人：女
# (
# 剛剛)   line False
# 陌生人：女
# (
# 剛剛)   女嗎 False
# 陌生人：女
# (
# 剛剛)   找女 False
# 陌生人：女
# (
# 剛剛)   叔 False
# 陌生人：女
# (
# 剛剛)   滾 False
# 陌生人：女
# (
# 剛剛)   台中 False
# 陌生人：女
# (
# 剛剛)   你媽 False
# 陌生人：女
# (
# 剛剛)   耖 False
# 陌生人：女
# (
# 剛剛)   機掰 False
# 陌生人：女
# (
# 剛剛)   雞掰 False
# 陌生人：女
# (
# 剛剛)   操 False
# 陌生人：女
# (
# 剛剛)   找妹 False
# 陌生人：女
# (
# 剛剛)   約嗎 False
# 抓到找女啦
# success
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 6
# 第 100 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：下午好
# (
# 剛剛)   男 False
# 陌生人：下午好
# (
# 剛剛)   賴 False
# 陌生人：下午好
# (
# 剛剛)   line False
# 陌生人：下午好
# (
# 剛剛)   女嗎 False
# 陌生人：下午好
# (
# 剛剛)   找女 False
# 陌生人：下午好
# (
# 剛剛)   叔 False
# 陌生人：下午好
# (
# 剛剛)   滾 False
# 陌生人：下午好
# (
# 剛剛)   台中 False
# 陌生人：下午好
# (
# 剛剛)   你媽 False
# 陌生人：下午好
# (
# 剛剛)   耖 False
# 陌生人：下午好
# (
# 剛剛)   機掰 False
# 陌生人：下午好
# (
# 剛剛)   雞掰 False
# 陌生人：下午好
# (
# 剛剛)   操 False
# 陌生人：下午好
# (
# 剛剛)   找妹 False
# 陌生人：下午好
# (
# 剛剛)   約嗎 False
# change_check= 0
# change_check 0
# note= 6
# 第 101 個有人回話未離開 陌生人：下午好
# (
# 剛剛)
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 102 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：腹肌?
# (
# 剛剛)   男 False
# 陌生人：腹肌?
# (
# 剛剛)   賴 False
# 陌生人：腹肌?
# (
# 剛剛)   line False
# 陌生人：腹肌?
# (
# 剛剛)   女嗎 False
# 陌生人：腹肌?
# (
# 剛剛)   找女 False
# 陌生人：腹肌?
# (
# 剛剛)   叔 False
# 陌生人：腹肌?
# (
# 剛剛)   滾 False
# 陌生人：腹肌?
# (
# 剛剛)   台中 False
# 陌生人：腹肌?
# (
# 剛剛)   你媽 False
# 陌生人：腹肌?
# (
# 剛剛)   耖 False
# 陌生人：腹肌?
# (
# 剛剛)   機掰 False
# 陌生人：腹肌?
# (
# 剛剛)   雞掰 False
# 陌生人：腹肌?
# (
# 剛剛)   操 False
# 陌生人：腹肌?
# (
# 剛剛)   找妹 False
# 陌生人：腹肌?
# (
# 剛剛)   約嗎 False
# change_check= 0
# change_check 0
# note= 6
# 第 103 個有人回話未離開 陌生人：腹肌?
# (
# 剛剛)
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 104 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 105 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 106 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 6
# 第 107 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：哈囉男生
# (
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：哈囉男生
# (
# 剛剛)   賴 False
# 陌生人：哈囉男生
# (
# 剛剛)   line False
# 陌生人：哈囉男生
# (
# 剛剛)   女嗎 False
# 陌生人：哈囉男生
# (
# 剛剛)   找女 False
# 陌生人：哈囉男生
# (
# 剛剛)   叔 False
# 陌生人：哈囉男生
# (
# 剛剛)   滾 False
# 陌生人：哈囉男生
# (
# 剛剛)   台中 False
# 陌生人：哈囉男生
# (
# 剛剛)   你媽 False
# 陌生人：哈囉男生
# (
# 剛剛)   耖 False
# 陌生人：哈囉男生
# (
# 剛剛)   機掰 False
# 陌生人：哈囉男生
# (
# 剛剛)   雞掰 False
# 陌生人：哈囉男生
# (
# 剛剛)   操 False
# 陌生人：哈囉男生
# (
# 剛剛)   找妹 False
# 陌生人：哈囉男生
# (
# 剛剛)   約嗎 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 109 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   找妹 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   約嗎 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 111 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 112 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 113 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：哈囉男生
# (
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：哈囉男生
# (
# 剛剛)   賴 False
# 陌生人：哈囉男生
# (
# 剛剛)   line False
# 陌生人：哈囉男生
# (
# 剛剛)   女嗎 False
# 陌生人：哈囉男生
# (
# 剛剛)   找女 False
# 陌生人：哈囉男生
# (
# 剛剛)   叔 False
# 陌生人：哈囉男生
# (
# 剛剛)   滾 False
# 陌生人：哈囉男生
# (
# 剛剛)   台中 False
# 陌生人：哈囉男生
# (
# 剛剛)   你媽 False
# 陌生人：哈囉男生
# (
# 剛剛)   耖 False
# 陌生人：哈囉男生
# (
# 剛剛)   機掰 False
# 陌生人：哈囉男生
# (
# 剛剛)   雞掰 False
# 陌生人：哈囉男生
# (
# 剛剛)   操 False
# 陌生人：哈囉男生
# (
# 剛剛)   找妹 False
# 陌生人：哈囉男生
# (
# 剛剛)   約嗎 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 115 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   台中 True
# 抓到白癡啦
# success
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   找妹 False
# 陌生人：台中男
# (
# 行動裝置
# 剛剛)   約嗎 False
# change_check= 2
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 118 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 119 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 120 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：新北男生21妳呢？
# (剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：新北男生21妳呢？
# (剛剛)   賴 False
# 陌生人：新北男生21妳呢？
# (剛剛)   line False
# 陌生人：新北男生21妳呢？
# (剛剛)   女嗎 False
# 陌生人：新北男生21妳呢？
# (剛剛)   找女 False
# 陌生人：新北男生21妳呢？
# (剛剛)   叔 False
# 陌生人：新北男生21妳呢？
# (剛剛)   滾 False
# 陌生人：新北男生21妳呢？
# (剛剛)   台中 False
# 陌生人：新北男生21妳呢？
# (剛剛)   你媽 False
# 陌生人：新北男生21妳呢？
# (剛剛)   耖 False
# 陌生人：新北男生21妳呢？
# (剛剛)   機掰 False
# 陌生人：新北男生21妳呢？
# (剛剛)   雞掰 False
# 陌生人：新北男生21妳呢？
# (剛剛)   操 False
# 陌生人：新北男生21妳呢？
# (剛剛)   找妹 False
# 陌生人：新北男生21妳呢？
# (剛剛)   約嗎 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 122 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 123 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 124 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 125 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 126 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 127 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   找妹 False
# 陌生人：新北男生21妳呢？
# (
# 行動裝置
# 剛剛)   約嗎 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 129 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 130 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 131 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 132 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 133 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：嗨嗨
# (
# App
# 剛剛)   男 False
# 陌生人：嗨嗨
# (
# App
# 剛剛)   賴 False
# 陌生人：嗨嗨
# (
# App
# 剛剛)   line False
# 陌生人：嗨嗨
# (
# App
# 剛剛)   女嗎 False
# 陌生人：嗨嗨
# (
# App
# 剛剛)   找女 False
# 陌生人：嗨嗨
# (
# App
# 剛剛)   叔 False
# 陌生人：嗨嗨
# (
# App
# 剛剛)   滾 False
# 陌生人：嗨嗨
# (
# App
# 剛剛)   台中 False
# 陌生人：嗨嗨
# (
# App
# 剛剛)   你媽 False
# 陌生人：嗨嗨
# (
# App
# 剛剛)   耖 False
# 陌生人：嗨嗨
# (
# App
# 剛剛)   機掰 False
# 陌生人：嗨嗨
# (
# App
# 剛剛)   雞掰 False
# 陌生人：嗨嗨
# (
# App
# 剛剛)   操 False
# 陌生人：嗨嗨
# (
# App
# 剛剛)   找妹 False
# 陌生人：嗨嗨
# (
# App
# 剛剛)   約嗎 False
# change_check= 0
# change_check 0
# note= 7
# 第 134 個有人回話已離開 陌生人：嗨嗨
# (
# App
# 剛剛)
# stop1 Message: element not interactable
#   (Session info: chrome=90.0.4430.212)
#
# stop1 Message: element not interactable
#   (Session info: chrome=90.0.4430.212)
#
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：男生
# (
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：男生
# (
# 剛剛)   賴 False
# 陌生人：男生
# (
# 剛剛)   line False
# 陌生人：男生
# (
# 剛剛)   女嗎 False
# 陌生人：男生
# (
# 剛剛)   找女 False
# 陌生人：男生
# (
# 剛剛)   叔 False
# 陌生人：男生
# (
# 剛剛)   滾 False
# 陌生人：男生
# (
# 剛剛)   台中 False
# 陌生人：男生
# (
# 剛剛)   你媽 False
# 陌生人：男生
# (
# 剛剛)   耖 False
# 陌生人：男生
# (
# 剛剛)   機掰 False
# 陌生人：男生
# (
# 剛剛)   雞掰 False
# 陌生人：男生
# (
# 剛剛)   操 False
# 陌生人：男生
# (
# 剛剛)   找妹 False
# 陌生人：男生
# (
# 剛剛)   約嗎 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 138 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 139 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 140 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 141 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 142 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 7
# 第 143 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 144 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 145 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 146 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 147 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 148 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 7
# 第 149 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 150 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 151 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 152 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 153 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 154 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 155 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 156 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 157 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 158 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：嗨
# (剛剛)   男 False
# 陌生人：嗨
# (剛剛)   賴 False
# 陌生人：嗨
# (剛剛)   line False
# 陌生人：嗨
# (剛剛)   女嗎 False
# 陌生人：嗨
# (剛剛)   找女 False
# 陌生人：嗨
# (剛剛)   叔 False
# 陌生人：嗨
# (剛剛)   滾 False
# 陌生人：嗨
# (剛剛)   台中 False
# 陌生人：嗨
# (剛剛)   你媽 False
# 陌生人：嗨
# (剛剛)   耖 False
# 陌生人：嗨
# (剛剛)   機掰 False
# 陌生人：嗨
# (剛剛)   雞掰 False
# 陌生人：嗨
# (剛剛)   操 False
# 陌生人：嗨
# (剛剛)   找妹 False
# 陌生人：嗨
# (剛剛)   約嗎 False
# change_check= 0
# change_check 0
# note= 6
# 第 159 個有人回話未離開 陌生人：嗨
# (剛剛)
# (error)def n= 159
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 160 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 161 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 162 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 163 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 164 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 165 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 166 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 167 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 168 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 169 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 170 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 171 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 172 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：嗨男生
# (
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：嗨男生
# (
# 剛剛)   賴 False
# 陌生人：嗨男生
# (
# 剛剛)   line False
# 陌生人：嗨男生
# (
# 剛剛)   女嗎 False
# 陌生人：嗨男生
# (
# 剛剛)   找女 False
# 陌生人：嗨男生
# (
# 剛剛)   叔 False
# 陌生人：嗨男生
# (
# 剛剛)   滾 False
# 陌生人：嗨男生
# (
# 剛剛)   台中 False
# 陌生人：嗨男生
# (
# 剛剛)   你媽 False
# 陌生人：嗨男生
# (
# 剛剛)   耖 False
# 陌生人：嗨男生
# (
# 剛剛)   機掰 False
# 陌生人：嗨男生
# (
# 剛剛)   雞掰 False
# 陌生人：嗨男生
# (
# 剛剛)   操 False
# 陌生人：嗨男生
# (
# 剛剛)   找妹 False
# 陌生人：嗨男生
# (
# 剛剛)   約嗎 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 174 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 175 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 176 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 177 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：我
# (
# App
# 剛剛)   男 False
# 陌生人：我
# (
# App
# 剛剛)   賴 False
# 陌生人：我
# (
# App
# 剛剛)   line False
# 陌生人：我
# (
# App
# 剛剛)   女嗎 False
# 陌生人：我
# (
# App
# 剛剛)   找女 False
# 陌生人：我
# (
# App
# 剛剛)   叔 False
# 陌生人：我
# (
# App
# 剛剛)   滾 False
# 陌生人：我
# (
# App
# 剛剛)   台中 False
# 陌生人：我
# (
# App
# 剛剛)   你媽 False
# 陌生人：我
# (
# App
# 剛剛)   耖 False
# 陌生人：我
# (
# App
# 剛剛)   機掰 False
# 陌生人：我
# (
# App
# 剛剛)   雞掰 False
# 陌生人：我
# (
# App
# 剛剛)   操 False
# 陌生人：我
# (
# App
# 剛剛)   找妹 False
# 陌生人：我
# (
# App
# 剛剛)   約嗎 False
# change_check= 0
# change_check 0
# note= 6
# 第 178 個有人回話未離開 陌生人：我
# (
# App
# 剛剛)
# (error)def n= 178
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 7
# 第 179 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 180 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：嗨男生
# (
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：嗨男生
# (
# 剛剛)   賴 False
# 陌生人：嗨男生
# (
# 剛剛)   line False
# 陌生人：嗨男生
# (
# 剛剛)   女嗎 False
# 陌生人：嗨男生
# (
# 剛剛)   找女 False
# 陌生人：嗨男生
# (
# 剛剛)   叔 False
# 陌生人：嗨男生
# (
# 剛剛)   滾 False
# 陌生人：嗨男生
# (
# 剛剛)   台中 False
# 陌生人：嗨男生
# (
# 剛剛)   你媽 False
# 陌生人：嗨男生
# (
# 剛剛)   耖 False
# 陌生人：嗨男生
# (
# 剛剛)   機掰 False
# 陌生人：嗨男生
# (
# 剛剛)   雞掰 False
# 陌生人：嗨男生
# (
# 剛剛)   操 False
# 陌生人：嗨男生
# (
# 剛剛)   找妹 False
# 陌生人：嗨男生
# (
# 剛剛)   約嗎 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 182 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 183 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 184 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 185 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 186 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 187 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 188 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：男
# (
# 行動裝置
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：男
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   找妹 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   約嗎 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 190 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：男生
# (
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：男生
# (
# 剛剛)   賴 False
# 陌生人：男生
# (
# 剛剛)   line False
# 陌生人：男生
# (
# 剛剛)   女嗎 False
# 陌生人：男生
# (
# 剛剛)   找女 False
# 陌生人：男生
# (
# 剛剛)   叔 False
# 陌生人：男生
# (
# 剛剛)   滾 False
# 陌生人：男生
# (
# 剛剛)   台中 False
# 陌生人：男生
# (
# 剛剛)   你媽 False
# 陌生人：男生
# (
# 剛剛)   耖 False
# 陌生人：男生
# (
# 剛剛)   機掰 False
# 陌生人：男生
# (
# 剛剛)   雞掰 False
# 陌生人：男生
# (
# 剛剛)   操 False
# 陌生人：男生
# (
# 剛剛)   找妹 False
# 陌生人：男生
# (
# 剛剛)   約嗎 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 192 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 193 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 194 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 195 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 7
# 第 196 個無人回話已離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 197 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：嗨
# (剛剛)   男 False
# 陌生人：嗨
# (剛剛)   賴 False
# 陌生人：嗨
# (剛剛)   line False
# 陌生人：嗨
# (剛剛)   女嗎 False
# 陌生人：嗨
# (剛剛)   找女 False
# 陌生人：嗨
# (剛剛)   叔 False
# 陌生人：嗨
# (剛剛)   滾 False
# 陌生人：嗨
# (剛剛)   台中 False
# 陌生人：嗨
# (剛剛)   你媽 False
# 陌生人：嗨
# (剛剛)   耖 False
# 陌生人：嗨
# (剛剛)   機掰 False
# 陌生人：嗨
# (剛剛)   雞掰 False
# 陌生人：嗨
# (剛剛)   操 False
# 陌生人：嗨
# (剛剛)   找妹 False
# 陌生人：嗨
# (剛剛)   約嗎 False
# change_check= 0
# change_check 0
# note= 6
# 第 198 個有人回話未離開 陌生人：嗨
# (剛剛)
# (error)def n= 198
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 199 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 200 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 201 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 202 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：三上悠亞
# (
# 行動裝置
# 剛剛)   男 False
# 陌生人：三上悠亞
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：三上悠亞
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：三上悠亞
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：三上悠亞
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：三上悠亞
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：三上悠亞
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：三上悠亞
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：三上悠亞
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：三上悠亞
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：三上悠亞
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：三上悠亞
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：三上悠亞
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：三上悠亞
# (
# 行動裝置
# 剛剛)   找妹 False
# 陌生人：三上悠亞
# (
# 行動裝置
# 剛剛)   約嗎 False
# change_check= 0
# change_check 0
# note= 6
# 第 203 個有人回話未離開 陌生人：三上悠亞
# (
# 行動裝置
# 剛剛)
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 5
# text_length五 5
# 第 204 個第一階段離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 6
# 第 205 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：男
# (
# 行動裝置
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：男
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   找妹 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   約嗎 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# stop5 Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.stranger.text"}
#   (Session info: chrome=90.0.4430.212)
#
# s= 6
# 第 207 個無人回話未離開
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：男
# (
# 行動裝置
# 剛剛)   男 True
# 抓到白癡啦
# success
# 陌生人：男
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   找妹 False
# 陌生人：男
# (
# 行動裝置
# 剛剛)   約嗎 False
# change_check= 1
# 系統訊息：加密連線完成，開始聊天囉！
# 起始text_length 4
# 有人回話
# 陌生人：幹嘛
# (
# 行動裝置
# 剛剛)   男 False
# 陌生人：幹嘛
# (
# 行動裝置
# 剛剛)   賴 False
# 陌生人：幹嘛
# (
# 行動裝置
# 剛剛)   line False
# 陌生人：幹嘛
# (
# 行動裝置
# 剛剛)   女嗎 False
# 陌生人：幹嘛
# (
# 行動裝置
# 剛剛)   找女 False
# 陌生人：幹嘛
# (
# 行動裝置
# 剛剛)   叔 False
# 陌生人：幹嘛
# (
# 行動裝置
# 剛剛)   滾 False
# 陌生人：幹嘛
# (
# 行動裝置
# 剛剛)   台中 False
# 陌生人：幹嘛
# (
# 行動裝置
# 剛剛)   你媽 False
# 陌生人：幹嘛
# (
# 行動裝置
# 剛剛)   耖 False
# 陌生人：幹嘛
# (
# 行動裝置
# 剛剛)   機掰 False
# 陌生人：幹嘛
# (
# 行動裝置
# 剛剛)   雞掰 False
# 陌生人：幹嘛
# (
# 行動裝置
# 剛剛)   操 False
# 陌生人：幹嘛
# (
# 行動裝置
# 剛剛)   找妹 False
# 陌生人：幹嘛
# (
# 行動裝置
# 剛剛)   約嗎 False
# change_check= 0
# change_check 0
# note= 6
# 第 209 個有人回話未離開 陌生人：幹嘛
# (
# 行動裝置
# 剛剛)
# stop1 Message: no such element: Unable to locate element: {"method":"css selector","selector":"#messages > div:nth-child(4)"}
#   (Session info: chrome=90.0.4430.212)

# %%
driver.implicitly_wait(10)
driver.find_element_by_id('changeButton').click()
driver.implicitly_wait(10)
driver.find_element_by_id("popup-yes").click()

# %%
driver.find_element_by_css_selector("#changeButton > input[value=\"離開\"]").click()

# %%
driver.implicitly_wait(10)
driver.find_element_by_id('startButton').click()
driver.implicitly_wait(10)
c=driver.find_element_by_id('messageInput')
driver.find_element_by_id("messageInput").clear()
c.send_keys('哈囉 女生')
driver.implicitly_wait(10)
driver.find_element_by_css_selector("#messages > div:nth-child(4)").text
driver.implicitly_wait(10)
c.send_keys(Keys.RETURN)
texts_length = len(driver.find_elements_by_xpath("//div[@class=\"system text \"]"))
print(driver.find_element_by_css_selector("#messages > div:nth-child(4)").text)
print(texts_length)
# Out:
# 系統訊息：加密連線完成，開始聊天囉！
# 4

# %%
ignore_array=["男","賴",'line','女嗎','找女','叔','滾','台中','幹娘','你媽','耖','機掰','雞掰','操']
                   
for i in range(0,len(ignore_array)):
    print(ignore_array[i])
# Out:
# 男
# 賴
# line
# 女嗎
# 找女
# 叔
# 滾
# 台中
# 幹娘
# 你媽
# 耖
# 機掰
# 雞掰
# 操

# %%
driver.find_element_by_css_selector("#messages > div:nth-child(4)").text
# Out:
# '今日 (12月25日)'
